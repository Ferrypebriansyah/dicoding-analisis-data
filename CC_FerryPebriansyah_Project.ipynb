# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Ferry Pebriansyah
# - **Email:** ferryfeb10@gmail.com
# - **ID Dicoding:**

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Apa saja kategori barang yang banyak dibeli dan sedikit dibeli oleh customer?
# 2. Method Payment apa saja yang banyak digunakan oleh customer?
# 3. Dimana wilayah negara bagian yang memiliki transaksi paling banyak?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Digunakan untuk analisis data
import numpy as np
import pandas as pd

# Digunakan untuk visualisasi data
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Meload data frame dataset Customers
print("CUSTOMERS TABLE")
customers_df = pd.read_csv("dataset/customers_dataset.csv", delimiter=",")

customers_df.head()
# Out:
# CUSTOMERS TABLE
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
# Meload data frame dataset Geolocation
print("GEOLOCATION TABLE")
geolocation_df = pd.read_csv("dataset/geolocation_dataset.csv", delimiter=",")

geolocation_df.head()
# Out:
# GEOLOCATION TABLE
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# Meload data frame order_items
print("ORDER ITEMS TABLE")
order_items_df = pd.read_csv("dataset/order_items_dataset.csv", delimiter=",")

order_items_df.head()
# Out:
# ORDER ITEMS TABLE
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# ...

# %%
# Meload data frame order_payments
print("ORDER PAYMENTS TABLE")
order_payments_df = pd.read_csv("dataset/order_payments_dataset.csv", delimiter=",")

order_payments_df.head()
# Out:
# ORDER PAYMENTS TABLE
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
# Meload data frame order_reviews
print("ORDER REVIEWS TABLE")
order_reviews_df = pd.read_csv("dataset/order_reviews_dataset.csv", delimiter=",")

order_reviews_df.head()
# Out:
# ORDER REVIEWS TABLE
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# ...

# %%
# Meload data frame orders
print("ORDERS TABLE")
orders_df = pd.read_csv("dataset/orders_dataset.csv", delimiter=",")

orders_df.head()
# Out:
# ORDERS TABLE
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# Meload data frame product category name translation
print("PRODUCT CATEGORY NAME TRANSLATION TABLE")
product_category_df = pd.read_csv("dataset/product_category_name_translation.csv", delimiter=",")

product_category_df.head()
# Out:
# PRODUCT CATEGORY NAME TRANSLATION TABLE
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
# Meload data frame products
print("PRODUCTS TABLE")
products_df = pd.read_csv("dataset/products_dataset.csv", delimiter=",")

products_df.head()
# Out:
# PRODUCTS TABLE
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# Meload data frame sellers
print("SELLERS TABLE")
sellers_df = pd.read_csv("dataset/sellers_dataset.csv", delimiter=",")

sellers_df.head(15)
# Out:
# SELLERS TABLE
#                            seller_id  seller_zip_code_prefix  \
# 0   3442f8959a84dea7ee197c632cb2df15                   13023
# 1   d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2   ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3   c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4   51a04a8a6bdcb23deccc82b0b80742cf                   12914
# 5   c240c4061717ac1806ae6ee72be3533b                   20920
# 6   e49c26c3edfa46d227d5121a6b6e4d37                   55325
# 7   1b938a7ec6ac5061a66a3766e0e75f90                   16304
# 8   768a86e36ad6aae3d03ee3c6433d61df                    1529
# 9   ccc4bbb5f32a6ab2b7066a4130f114e3                   80310
# 10  8cb7c5ddf41f4d506eba76e9a4702a25                   75110
# 11  a7a9b880c49781da66651ccf4ba9ac38                   13530
# 12  8bd0f31cf0a614c658f6763bd02dea69                    1222
# 13  05a48cc8859962767935ab9087417fbb                    5372
# ...

# %% [markdown]
# **Insight:**
# - customers_dataset: Berisi informasi tentang data csutomer seperti id, domisili, kode wilayah, dll.
# - geolocations_dataset: Berisi informasi wilayah geografis seperti kode pos, koordinat, nama kota, dll.
# - order_items_dataset: Berisi informasi order yang dilakukan csutomer seperti ongkir pengiriman, dan berat pengiriman.
# - order_reviews_dataset: Berisi review ulasan dan rating penilaian produk.
# - orders_dataset: Berisi informasi status pengiriman produk seperti tanggal pengiriman, tanggal sampai, dan status order.
# - product_category_name_dataset: Berisi informasi kategori produk yang memiliki terjemahan ke bahasa inggris.
# - products_dataset: Berisi informasi detail dari sebuah produk seperti kategori produk, berat produk, ukuran produk, dll.
# - sellers_dataset: Berisi informasi tentang domisili seller seperti koordinat kota, nama kota, dll.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# 1. Menilai data customers_dataset

# %%
print("Info Data Frame")
customers_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Info missing value")
customers_df.isna().sum()
# Out:
# Info missing value
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
customers_df.describe()
# Out:
# Deskripsi Statistik
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# 2. Menilai data geolocations_df

# %%
print("Info Data Frame")
geolocation_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698744 entries, 0 to 698743
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  698744 non-null  int64
#  1   geolocation_lat              698744 non-null  float64
#  2   geolocation_lng              698744 non-null  float64
#  3   geolocation_city             698744 non-null  object
#  4   geolocation_state            698743 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 26.7+ MB

# %%
print("Info missing value")
geolocation_df.isna().sum()
# Out:
# Info missing value
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              1
# dtype: int64

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  196950

# %%
print("Deskripsi Statistik")
geolocation_df.describe()
# Out:
# Deskripsi Statistik
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                698744.000000    698744.000000    698744.000000
# mean                  18377.828239       -21.993107       -45.429131
# std                   12501.190817         2.434807         2.511358
# min                    1001.000000       -34.622400      -101.466766
# 25%                    6807.000000       -23.543316       -46.755217
# 50%                   15091.000000       -22.909776       -46.501130
# 75%                   28960.000000       -21.173843       -43.449630
# max                   47590.000000        43.684961        13.820214

# %% [markdown]
# 3. Menilai data order_items_df

# %%
print("Info Data Frame")
order_items_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Info missing value")
order_items_df.isna().sum()
# Out:
# Info missing value
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
order_items_df.describe()
# Out:
# Deskripsi Statistik
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# 4. Menilai data order_payments_df

# %%
print("Info Data Frame")
order_payments_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Info missing value")
order_payments_df.isna().sum()
# Out:
# Info missing value
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_payments_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
order_payments_df.describe()
# Out:
# Deskripsi Statistik
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# 5. Menilai data order_reviews_df

# %%
print("Info Data Frame")
order_reviews_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
print("Info missing value")
order_reviews_df.isna().sum()
# Out:
# Info missing value
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_reviews_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
order_reviews_df.describe()
# Out:
# Deskripsi Statistik
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# 6. Menilai data orders_df

# %%
print("Info Data Frame")
orders_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
print("Info missing value")
orders_df.isna().sum()
# Out:
# Info missing value
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
orders_df.describe()
# Out:
# Deskripsi Statistik
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# 7. Menilai data product_category_df

# %%
print("Info Data Frame")
product_category_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Info missing value")
product_category_df.isna().sum()
# Out:
# Info missing value
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_category_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
product_category_df.describe()
# Out:
# Deskripsi Statistik
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# 8. Menilai data products_df

# %%
print("Info Data Frame")
products_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print("Info missing value")
products_df.isna().sum()
# Out:
# Info missing value
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
products_df.describe()
# Out:
# Deskripsi Statistik
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# 9. Menilai data sellers_df

# %%
print("Info Data Frame")
sellers_df.info()
# Out:
# Info Data Frame
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
print("Info missing value")
sellers_df.isna().sum()
# Out:
# Info missing value
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print("Deskripsi Statistik")
sellers_df.describe()
# Out:
# Deskripsi Statistik
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# **Insight:**
#
# Hal-hal yang diperoleh dari setiap dataframe yang sudah dinilai:
# 1. customer_df
# - Dataset ini tidak memiliki masalah.
#
# 2. geolocation_df
# - Dataset ini memiliki kesalahan yaitu terdapat **duplikasi data** sebanyak 261831 record data.
#
# 3. order_items_df
# - Dataset ini memiliki kesalahan **tipe data** pada field shipping_limit_date.
#
# 4. order_payments_df
# - Dataset ini tidak memiliki masalah.
#
# 5. order_reviews_df
# - Dataset ini memiliki **missing value** pada field review_comment_title sebanyak 87.656 nilai, dan review_comment_message sebanyak 58.247 nilai.
#
# 6. orders_df
# - Dataset ini memiliki kesalahan **tipe data** pada field order_purchase_timestamp, order_aproved_at, order_delivered_carrier_date, order_delivered_customer_date, dan order_estimated_delivery_date.
# - Dataset ini memiliki **missing value** order_approved_at sebanyak 160 nilai, order_delivered_carrier_date sebanyak 1783 nilai, dan order_delivered_customer_date sebannyak 1783 nilai.
#
# 7. product_category_df
# - Dataset ini tidak memiliki masalah.
#
# 8. products_df
#
# Dataset ini memiliki **missing value** yaitu:
# - Sebanyak 610 nilai pada field product_category_name, product_name_length, dan products_photos_qty.
# - Sebanyak 2 nilai pada field product_weight_g, product_length_cm, product_height_cm, dan product_width_cm
#
# 9. sellers_df
# - Dataset ini tidak memiliki masalah.
#
# **Kesimpulan**
#
# Kesalahan yang perlu diperbaiki dari insight diatas:
# 1. Mengubah tipe data field sesuai kategorinya.
# 2. Memustuskan apakah harus menghapus record duplicate data atau mempertahankannya tergantung dengan isi datanya.
# 3. Menghapus data jika presentase missing valuenya kurang dari 1%.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# 1. Memperbaiki tipe data

# %%
# Mengubah tipe data kolom shipping_limit_date dari object menjadi datetime pada order_items_df
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
# Mengubah tipe data dibeberapa kolom dari object menjadi datetime pada orders_df
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# 2. Menangani duplicate data

# %%
print("Jumlah duplikasi: ",geolocation_df.duplicated().sum())
geolocation_df[geolocation_df.duplicated()].groupby("geolocation_zip_code_prefix").size().sort_values(ascending=False)
# Out:
# Jumlah duplikasi:  196950
# geolocation_zip_code_prefix
# 24230    724
# 22631    690
# 24220    648
# 6454     435
# 30140    430
#         ...
# 4385       1
# 19024      1
# 19027      1
# 37527      1
# 47590      1
# Length: 9176, dtype: int64

# %%
print("Jumlah duplikasi: ",geolocation_df.duplicated().sum())
geolocation_df[geolocation_df.duplicated()].groupby("geolocation_lat").size().sort_values(ascending=False)
# Out:
# Jumlah duplikasi:  196950
# geolocation_lat
# -23.495901    188
# -23.506049    139
# -23.490618    126
# -23.005514    101
# -22.965906     88
#              ...
# -23.084245      1
# -23.083899      1
# -23.083871      1
# -23.083846      1
# -3.107535       1
# Length: 87670, dtype: int64

# %% [markdown]
# *Kesimpulan:
# Data Frame ini tidak saya hapus(drop), karena contohnya setiap kolom geolocation_zip_code_prefix memiliki geolocation_lat yang berbeda-beda. begitu juga dengan relasi anatara kolom-kolom yang lainnya. ini menandakan dataset ini berisi indo tentang detail lokasi seller dan customer

# %% [markdown]
# 3. Menangani Missing Value

# %% [markdown]
# - **order_reviews_df**

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_reviews_df[order_reviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_df[order_reviews_df.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %%
missing_ratio = order_reviews_df['review_comment_title'].isnull().mean() * 100
print(f"Persentase missing values pada field review_comment_title: {missing_ratio:.2f}%")

missing_ratio = order_reviews_df['review_comment_message'].isnull().mean() * 100
print(f"Persentase missing values pada field review_comment_message: {missing_ratio:.2f}%")
# Out:
# Persentase missing values pada field review_comment_title: 88.34%
# Persentase missing values pada field review_comment_message: 58.70%

# %% [markdown]
# **kesimpulan:** Kedua field pada order_reviews_df tidak perlu dihapus dikarenakan tidak mempengaruhi kualitas data karena rata-rata pada setiap E-commerce pengguna tidak wajib memberikan rating pada setiap produk yang diorder.

# %% [markdown]
# - **orders_df**

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders_df.order_status.value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
# orders_df[orders_df["order_status"] == "delivered"]
# orders_df[orders_df["order_status"] == "shipped"]
orders_df[orders_df["order_status"] == "canceled"]
# orders_df[orders_df["order_status"] == "unavailable"]
# orders_df[orders_df["order_status"] == "invoiced"]
# orders_df[orders_df["order_status"] == "processing"]
# orders_df[orders_df["order_status"] == "created"]
# orders_df[orders_df["order_status"] == "approved"]
# Out:
#                                order_id                       customer_id  \
# 397    1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 613    714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 1058   3a129877493c8189c59c60eb71d97c29  0913cdce793684e52bbfac69d87e91fd
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# ...                                 ...                               ...
# 98791  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99143  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
orders_df[orders_df.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
orders_df[orders_df.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# **kesimpulan:** Ketiga field yang memiliki missing value diatas tidak perlu saya hapus karena ketika saya cek setiap kategori order_status memiliki proses yang berbeda-beda. contoh pada kasus diatas ketika order_status "delivered" maka ketiga field tersebut terisi semua karena produk sudah sampai ke lokasi customer. Namun untuk order status "shipped" maka otomatis kolom order_delivered_carrier_date terisi karena produk sedang dalam pengiriman.
#
# Intinya setiap kategori order_status memiliki fungsi yang berbeda-beda

# %% [markdown]
# - **products_df**

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df[products_df.product_weight_g.isna()]
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
products_df = products_df[products_df["product_id"] != "5eb564652db742ff8f28759cd8d2652a"]

# %%
products_df[products_df["product_id"] == "5eb564652db742ff8f28759cd8d2652a"]
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %% [markdown]
# **kesimpulan:** Pada data frame ini saya hanya menghapus 1 record produk_id saja karena sama sekali tidak memiliki deskripsi satupun.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# 1. Menggabungkan(merge) data order_item_df dan products_df untuk mencari total order di setiap kategori produk

# %%
#memastikan adanya field yang saling terhubung
order_items_df.info()
products_df.info()
# product_category_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 32950 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32950 non-null  object
# ...

# %% [markdown]
# - Saya mendapatkan hubungan kedua data tersebut yaitu data frame order_items dengan data frame products_df melalui field product_id

# %%
# Menggabungkan data frame order_items_df dengan products_df melalui field product_id
totals_product_df = order_items_df.merge(products_df, on="product_id", how="left")
totals_product_df
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
category_counts = totals_product_df.groupby("product_category_name")["order_id"].count().reset_index()

# %%
totals_product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   order_id                    112650 non-null  object
#  1   order_item_id               112650 non-null  int64
#  2   product_id                  112650 non-null  object
#  3   seller_id                   112650 non-null  object
#  4   shipping_limit_date         112650 non-null  datetime64[ns]
#  5   price                       112650 non-null  float64
#  6   freight_value               112650 non-null  float64
#  7   product_category_name       111047 non-null  object
#  8   product_name_lenght         111047 non-null  float64
#  9   product_description_lenght  111047 non-null  float64
#  10  product_photos_qty          111047 non-null  float64
#  11  product_weight_g            112632 non-null  float64
# ...

# %%
# Membuat dan mencetak kolom untuk menampilkan kategori product terbanyak diorder
category_counts.columns = ["product_category_name", "total_orders"]
top_categories = category_counts.sort_values(by="total_orders", ascending=False)
print(top_categories.head(10))
# Out:
#      product_category_name  total_orders
# 13         cama_mesa_banho         11115
# 11            beleza_saude          9670
# 32           esporte_lazer          8641
# 54        moveis_decoracao          8334
# 44  informatica_acessorios          7827
# 72   utilidades_domesticas          6964
# 66      relogios_presentes          5991
# 70               telefonia          4545
# 40      ferramentas_jardim          4347
# 8               automotivo          4235

# %%
# Membuat dan mencetak kolom untuk menampilkan kategori product jarang dibeli
category_counts.columns = ["product_category_name", "total_orders"]
bottom_categories = category_counts.sort_values(by="total_orders", ascending=True)
print(bottom_categories.head(10))
# Out:
#                             product_category_name  total_orders
# 67                             seguros_e_servicos             2
# 37                  fashion_roupa_infanto_juvenil             8
# 60                                       pc_gamer             9
# 46                                     la_cuisine            14
# 17                              cds_dvds_musicais            14
# 65  portateis_cozinha_e_preparadores_de_alimentos            15
# 4                              artes_e_artesanato            24
# 35                                fashion_esporte            30
# 15                                casa_conforto_2            30
# 41                                         flores            33

# %% [markdown]
# 2. Mendapatkan data banyaknya presentase penggunaan method pada data frame order_payments.

# %%
# Melihat info field pada data frame order_payments_df
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
# Mencetak total payment_type dari daat frame order_payments_df
payment_counts = order_payments_df["payment_type"].value_counts()
print(payment_counts)
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
# Mencetak presentase payment_type dari data frame order_payments_d
payment_percentages = order_payments_df["payment_type"].value_counts(normalize=True) * 100
print(payment_percentages)
# Out:
# payment_type
# credit_card    73.922376
# boleto         19.043952
# voucher         5.558978
# debit_card      1.471806
# not_defined     0.002888
# Name: proportion, dtype: float64

# %% [markdown]
# 3. Mencari total order disetiap customer_state

# %%
# Menggabungkan data frame orders dengan customers untuk mendapatkan customer_state
most_orders = orders_df.merge(customers_df, on="customer_id", how="left")

# Menggabungkan most_orders dengan order_items untuk mendapatkan jumlah transaksi yang valid
most_orders = most_orders.merge(order_items_df, on="order_id", how="inner")

# Menghitung jumlah transaksi per state
state_transaction_counts = most_orders["customer_state"].value_counts().reset_index()

# Mengubah nama kolom agar lebih informatif
state_transaction_counts.columns = ["customer_state", "total_orders"]

# Menampilkan hasil
print(state_transaction_counts)
# Out:
#    customer_state  total_orders
# 0              SP         47449
# 1              RJ         14579
# 2              MG         13129
# 3              RS          6235
# 4              PR          5740
# 5              SC          4176
# 6              BA          3799
# 7              DF          2406
# 8              GO          2333
# 9              ES          2256
# 10             PE          1806
# 11             CE          1478
# 12             PA          1080
# 13             MT          1055
# 14             MA           824
# 15             MS           819
# 16             PB           602
# 17             PI           542
# 18             RN           529
# 19             AL           444
# 20             SE           385
# 21             TO           315
# 22             RO           278
# 23             AM           165
# 24             AC            92
# 25             AP            82
# 26             RR            52

# %%
merged_df = totals_product_df.merge(most_orders, on="order_id", how="inner")

all_df = merged_df.merge(order_payments_df, on="order_id", how="inner")

all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163677 entries, 0 to 163676
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       163677 non-null  object
#  1   order_item_id_x                163677 non-null  int64
#  2   product_id_x                   163677 non-null  object
#  3   seller_id_x                    163677 non-null  object
#  4   shipping_limit_date_x          163677 non-null  datetime64[ns]
#  5   price_x                        163677 non-null  float64
#  6   freight_value_x                163677 non-null  float64
#  7   product_category_name          161400 non-null  object
#  8   product_name_lenght            161400 non-null  float64
#  9   product_description_lenght     161400 non-null  float64
#  10  product_photos_qty             161400 non-null  float64
#  11  product_weight_g               163653 non-null  float64
# ...

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163677 entries, 0 to 163676
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       163677 non-null  object
#  1   order_item_id_x                163677 non-null  int64
#  2   product_id_x                   163677 non-null  object
#  3   seller_id_x                    163677 non-null  object
#  4   shipping_limit_date_x          163677 non-null  datetime64[ns]
#  5   price_x                        163677 non-null  float64
#  6   freight_value_x                163677 non-null  float64
#  7   product_category_name          161400 non-null  object
#  8   product_name_lenght            161400 non-null  float64
#  9   product_description_lenght     161400 non-null  float64
#  10  product_photos_qty             161400 non-null  float64
#  11  product_weight_g               163653 non-null  float64
# ...

# %% [markdown]
# **Insight:**
# - Hampir semua customer menggunakan payment_type Credit Card
# - Sao Paulo (SP) terlibat total_orders paling banyak
# - cama_mesa_banho merupakan kategori produk terbanyak yang dibeli

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Apa saja kategori barang yang banyak dan jarang dibeli oleh customer?

# %% [markdown]
# - Barang dengan pesanan terbanyak

# %%
# Menampilkan 10 kategori teratas
top_categories = top_categories.head(10)

# Membuat bar chart
plt.figure(figsize=(12, 6))
sns.barplot(
    x="total_orders",
    y="product_category_name",
    data=top_categories,  # Gunakan parameter data untuk meningkatkan keterbacaan
    palette="Blues_r",
    hue="product_category_name",  # Sesuai aturan baru Seaborn
    legend=False  # Menghindari legend yang tidak diperlukan
)

plt.xlabel("Total Orders")
plt.ylabel("Product Category Name")
plt.title("Top 10 Most Ordered Product Categories")
plt.show()

# %% [markdown]
# - Barang yang sedikit dipesan

# %%
# Menampilkan 10 kategori dengan jumlah pesanan paling sedikit
bottom_categories = bottom_categories.head(10)

# Membuat bar chart untuk kategori dengan pesanan paling sedikit
plt.figure(figsize=(12, 6))
sns.barplot(
    x="total_orders",
    y="product_category_name",
    data=bottom_categories,  # Menggunakan parameter data agar lebih bersih
    palette="Reds_r",
    hue="product_category_name",  # Menyesuaikan dengan versi terbaru Seaborn
    legend=False  # Menghindari legend yang tidak diperlukan
)

plt.xlabel("Total Orders")
plt.ylabel("Product Category Name")
plt.title("Bottom 10 Least Ordered Product Categories")
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Method Payment apa saja yang banyak digunakan oleh customer?

# %%
payment_counts = all_df['payment_type'].value_counts(normalize=True).reset_index()
payment_counts.columns = ['payment_type', 'percentage']

# Membuat bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    data=payment_counts,
    x="payment_type",
    y="percentage",
    hue="payment_type",  # Menjadikan x sebagai hue
    palette="Blues_d",
    legend=False  # Menghilangkan legend
)

plt.title("Distribusi Jenis Pembayaran", fontsize=18)
plt.xlabel("Jenis Pembayaran", fontsize=14)
plt.ylabel("Persentase", fontsize=14)

# Menambahkan teks nilai di atas bar
for i, v in enumerate(payment_counts["percentage"]):
    plt.text(i, v + 0.01, f'{v*100:.1f}%', ha='center', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 3: Dimana wilayah negara bagian yang memiliki transaksi paling banyak?

# %%
# Mengurutkan data terbanyak dari transaksi
state_transaction_counts = state_transaction_counts.sort_values(by="total_orders", ascending=False)

# Membuat bar chart
plt.figure(figsize=(12, 6))
sns.barplot(
    x="customer_state",
    y="total_orders",
    data=state_transaction_counts,
    palette="Blues_r",
    hue="customer_state",
    legend=False
)

# Menambahkan judul dan label
plt.title("Jumlah Transaksi per Negara Bagian", fontsize=14)
plt.xlabel("Customer State", fontsize=12)
plt.ylabel("Total Orders", fontsize=12)
plt.xticks(rotation=45)

# Menampilkan plot
plt.show()

# %% [markdown]
# **Insight:**
# - cama_mesa_banho merupakan produk paling laris dan seguros_e_servicos paling sedikit dibeli oleh customer.
# - method payment credit card paling sering dan banyak digunakan oleh para customer dibandingkan method yang lainnya.
# - sao paulo (SP) menduduki peringkat pertama dengan total transaksi melebihi 40000 orderan

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# # RFM Analisis

# %%
# Mengambil data transaksi terbaru
reference_date = all_df['order_purchase_timestamp'].max()

# Menghitung RFM dengan metode groupby dan aggregat
rfm = all_df.groupby('customer_id').agg({
    'order_purchase_timestamp': lambda x: (reference_date - x.max()).days,  # Recency > mengambil record beberapa hari terakhi
    'order_id': 'count',  # Frequency > mengambil total penjumlahan record order terbanyak yang dilakukan oleh customer
    'payment_value': 'sum'  # Monetary > mengambil total pengeluaran terbanyak yang dilakukan oleh customer
}).reset_index()

# Mengubah nama kolom
rfm.columns = ['customer_id', 'Recency', 'Frequency', 'Monetary']

# Menampilkan 5 customer terbaik berdasarkan setiap kategori RFM
top_recency = rfm.nsmallest(5, 'Recency')
top_frequency = rfm.nlargest(5, 'Frequency')
top_monetary = rfm.nlargest(5, 'Monetary')

# Menampilkan hasil kalkulasi FRM
print("Top 5 Customers by Recency (Transaksi Terbaru):")
print(top_recency)

print("\nTop 5 Customers by Frequency (Jumlah Order Terbanyak):")
print(top_frequency)

print("\nTop 5 Customers by Monetary (Total Pengeluaran Terbanyak):")
print(top_monetary)
# Out:
# Top 5 Customers by Recency (Transaksi Terbaru):
#                             customer_id  Recency  Frequency  Monetary
# 29063  4b7decb9b58e2569548b8b4c8e20e8d7        0          1    166.46
# 6357   10a79ef2783cae3d8d678e85fde235ac        4          1     14.29
# 28259  496630b6740bcca28fce9ba50d8a26ef        4          1     33.23
# 32387  54365416b7ef5599f54a6c7821d5d290        4          1    106.95
# 33320  56b1ac2855cc6d7950b4ffa6a9b41b0d        4          1    119.42
#
# Top 5 Customers by Frequency (Jumlah Order Terbanyak):
#                             customer_id  Recency  Frequency   Monetary
# 97219  fc3d1daec319d62d49bfb5e1f83123e9      413        441   86484.51
# 73310  bd5d39761aa56689a265d95d8d32b8be      375        400  905120.00
# 73567  be1b70680b9f9694d8c70f41fa3dc92b      192        400  880960.00
# 6456   10de381f8a8d23fff822753305f71cae      283        225  275771.25
# 67105  adb32467ecc74b53576d9d13a5a55891      580        225  176175.00
#
# ...

# %%
# Membuat plots untuk visualisasi
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot Recency
sns.barplot(ax=axes[0], y=top_recency['customer_id'].astype(str), x=top_recency['Recency'], hue=top_recency['customer_id'].astype(str), palette='Blues', legend=False)
axes[0].set_title("Top 5 Customers by Recency (days)")
axes[0].set_xlabel("Recency (days)")
axes[0].set_ylabel("Customer ID")

# Plot Frequency
sns.barplot(ax=axes[1], y=top_frequency['customer_id'].astype(str), x=top_frequency['Frequency'], hue=top_frequency['customer_id'].astype(str), palette='Greens', legend=False)
axes[1].set_title("Top 5 Customers by Frequency")
axes[1].set_xlabel("Frequency (Total Orders)")
axes[1].set_ylabel("Customer ID")

# Plot Monetary
sns.barplot(ax=axes[2], y=top_monetary['customer_id'].astype(str), x=top_monetary['Monetary'], hue=top_monetary['customer_id'].astype(str), palette='Oranges', legend=False)
axes[2].set_title("Top 5 Customers by Monetary Value")
axes[2].set_xlabel("Monetary (Total Spending)")
axes[2].set_ylabel("Customer ID")

# Menyesuaikan tata letak dan menampilkan Plot yang sudah dibuat
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Apa saja kategori barang yang banyak dibeli dan sedikit dibeli oleh customer?
# >   Cama_mesa_banho merupakan produk paling banyak dibeli oleh customer, kemudian seguros_e_servicos merupakan produk paling sedikit dibeli oleh customer.
# 2. Method Payment apa saja yang banyak digunakan oleh customer?
# > Method payment yang sering dipakai oleh customer yaitu Credit card yang tembus hingga 73% dari semua customer.
# 3. Dimana wilayah negara bagian yang memiliki transaksi paling banyak?
# > Sao Paulo(SP) paling banyak atas menduduki transaksi paling banyak dibanding ibu kota yang lainnya.

# %%
all_df.to_csv("all_df.csv", index=False)
